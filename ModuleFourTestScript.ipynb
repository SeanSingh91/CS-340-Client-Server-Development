# %%
# Python Testing Script

from CRUD_Python_Module import AnimalShelter

username = "aacuser"
password = "PAWAN"

shelter = AnimalShelter(username, password)
print("Connected -- shelter object is ready.")

new_animal = {
    "animal_id": "TEST1001",
    "animal_type": "Dog",
    "breed": "Labrador Retriever Mix",
    "name": "Milestone Test Pup",
    "outcome_type": "Adoption"
}
insert_success = shelter.create(new_animal)
print(f"Insert succeeded: {insert_success}")

results = shelter.read({"animal_id": "TEST1001"})
print(f"Documents found: {len(results)}")
print(results)
# Out:
# Connected -- shelter object is ready.
# Insert succeeded: True
# Documents found: 4
# [{'_id': ObjectId('6aae1f37001765ab8f4c5e88'), 'animal_id': 'TEST1001', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'name': 'Milestone Test Pup', 'outcome_type': 'Adoption'}, {'_id': ObjectId('6aae1ff4ad8149369520363c'), 'animal_id': 'TEST1001', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'name': 'Milestone Test Pup', 'outcome_type': 'Adoption'}, {'_id': ObjectId('6aae2331ad8149369520363e'), 'animal_id': 'TEST1001', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'name': 'Milestone Test Pup', 'outcome_type': 'Adoption'}, {'_id': ObjectId('6aae233fea03880afe465828'), 'animal_id': 'TEST1001', 'animal_type': 'Dog', 'breed': 'Labrador Retriever Mix', 'name': 'Milestone Test Pup', 'outcome_type': 'Adoption'}]

# %%
dog_results = shelter.read({"animal_type": "Dog"})
print(f"Dog records found: {len(dog_results)}")
print(dog_results[:3])
# Out:
# Dog records found: 5593
# ...
